# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
teachers= pd.read_excel(r"C:\Users\rawat\Downloads\teachersattritiondata.xlsx")
teachers.head(17)
# Out:
#     Year  Public Schools (Teachers Leaving)  Public Schools (% Leaving)  \
# 0   2007                              65000                         5.7
# 1   2008                              63500                         5.6
# 2   2009                              62000                         5.5
# 3   2010                              60000                         5.4
# 4   2011                              58000                         5.3
# 5   2012                              57500                         5.2
# 6   2013                              56000                         5.1
# 7   2014                              55000                         5.0
# 8   2015                              54500                         4.9
# 9   2016                              53000                         4.8
# 10  2017                              52000                         4.7
# 11  2018                              51500                         4.6
# 12  2019                              50000                         4.5
# 13  2020                              48500                         4.4
# 14  2021                              47000                         4.3
# 15  2022                              46500                         4.2
# 16  2023                              45000                         4.0
#
#     Private Schools (Teachers Leaving)  Private Schools (% Leaving)
# 0                                55500                          8.7
# 1                                54000                          8.5
# 2                                52500                          8.2
# 3                                50000                          8.0
# 4                                47500                          7.5
# 5                                46000                          7.3
# 6                                44500                          7.2
# 7                                43000                          7.0
# 8                                41500                          6.8
# 9                                40000                          6.6
# 10                               38500                          6.5
# 11                               37000                          6.3
# 12                               35500                          6.2
# 13                               34000                          6.0
# 14                               33000                          5.8
# 15                               31500                          5.6
# 16                               30000                          5.5

# %%
plt.plot(teachers['Year'], teachers['Public Schools (% Leaving)'], marker='o')
plt.title('Year vs leaving_rate')
plt.xlabel('Year')
plt.ylabel('Public Schools (% Leaving)')
plt.grid(True)
plt.show()

# %%
plt.plot(teachers['Year'], teachers['Private Schools (% Leaving)'], marker='o')
plt.title('Year vs leaving_rate')
plt.xlabel('Year')
plt.ylabel('Private Schools (% Leaving)')
plt.grid(True)
plt.show()
