# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
analysis_trend = pd.read_excel(r"C:\Users\rawat\Downloads\year wise data.xlsx")
analysis_trend.head(17)
# Out:
#     Year     India      USA       UK  Australia  Canada
# 0   2007  26000000  4300000  1400000     900000  800000
# 1   2008  27100000  4400000  1420000     920000  820000
# 2   2009  28200000  4450000  1450000     940000  830000
# 3   2010  29000000  4500000  1460000     950000  840000
# 4   2011  29500000  4550000  1470000     960000  850000
# 5   2012  30000000  4600000  1480000     970000  860000
# 6   2013  30500000  4650000  1490000     980000  870000
# 7   2014  31000000  4700000  1500000     990000  880000
# 8   2015  31500000  4750000  1510000    1000000  890000
# 9   2016  32000000  4800000  1520000    1010000  900000
# 10  2017  32500000  4850000  1530000    1020000  910000
# 11  2018  33000000  4900000  1540000    1030000  920000
# 12  2019  33500000  4950000  1550000    1040000  930000
# 13  2020  30000000  4000000  1200000     850000  800000
# 14  2021  29500000  3900000  1150000     800000  750000
# 15  2022  30500000  4100000  1250000     870000  780000
# 16  2023  29800000  4050000  1230000     860000  770000

# %%
#plot graph
sns.barplot(x = "Year",y= "India", data= analysis_trend,estimator="sum")
# Out:
# <Axes: xlabel='Year', ylabel='India'>

# %%
import matplotlib.pyplot as plt

# %%
trend = pd.read_excel(r"C:\Users\rawat\Downloads\KEY FACTORS.xlsx")
trend.head(100)
# Out:
#     Year  Enrollment Growth Rate (%)  Govt Expenditure on Education (%)  \
# 0   2007                         4.5                                3.2
# 1   2008                         4.2                                3.4
# 2   2009                         4.1                                3.6
# 3   2010                         2.8                                3.7
# 4   2011                         1.7                                3.9
# 5   2012                         1.9                                4.0
# 6   2013                         1.7                                4.2
# 7   2014                         1.6                                4.4
# 8   2015                         1.6                                4.5
# 9   2016                         1.5                                4.7
# 10  2017                         1.4                                4.8
# 11  2018                         1.3                                4.9
# 12  2019                         1.5                                5.0
# 13  2020                       -10.4                                5.1
# 14  2021                        -1.7                                5.3
# 15  2022                         3.4                                5.4
# 16  2023                        -2.3                                5.2
#
#     GDP Growth Rate (%)                        Key Impacts  \
# 0                   8.2           Launch of ICDS expansion
# 1                   7.2  Increased investment in education
# 2                   8.5          Implementation of RTE Act
# 3                  10.3   Expansion of mid-day meal scheme
# 4                   6.6       Policy on Right to Education
# 5                   5.5       Education for All initiative
# 6                   6.4              Launch of Skill India
# 7                   7.4      National Early Childhood Care
# 8                   8.0           Digital India initiative
# 9                   8.2                 GST implementation
# 10                  7.0             National Health Policy
# 11                  6.1             Ayushman Bharat launch
# 12                  4.2                  Education reforms
# 13                 -7.0                  COVID-19 pandemic
# 14                  8.9                    COVID-19 impact
# 15                  6.7                   Recovery efforts
# 16                  7.0        Post-COVID recovery efforts
#
#     Public Enrollments  Private Enrollments  Unemployment Rate (%)  \
# 0             16000000             10000000                    4.0
# 1             16800000             10300000                    4.1
# 2             17600000             10600000                    4.5
# 3             18300000             10700000                    4.3
# 4             19000000             10500000                    4.7
# 5             19400000             10600000                    5.2
# 6             19700000             10800000                    4.9
# 7             20000000             11000000                    4.7
# 8             20300000             11200000                    4.6
# 9             20600000             11400000                    4.5
# 10            20900000             11600000                    4.4
# 11            21200000             11800000                    4.3
# 12            21500000             12000000                    5.0
# 13            18000000             12000000                    8.0
# 14            18000000             11500000                    7.5
# 15            18500000             12000000                    7.0
# 16            18200000             11600000                    6.8
#
#     Birth Rate (per 1000)  Death Rate (per 1000)
# 0                    22.0                    7.6
# 1                    21.8                    7.5
# 2                    21.5                    7.4
# 3                    21.3                    7.3
# 4                    21.1                    7.2
# 5                    20.9                    7.1
# 6                    20.7                    7.0
# 7                    20.5                    6.9
# 8                    20.3                    6.8
# 9                    20.1                    6.7
# 10                   19.9                    6.6
# 11                   19.7                    6.5
# 12                   19.5                    6.4
# 13                   19.3                    7.0
# 14                   19.1                    6.8
# 15                   18.9                    6.7
# 16                   18.7                    6.6

# %%
plt.plot(trend['Year'], trend['Enrollment Growth Rate (%)'],marker='o')
plt.title('Year vs Enrollment_Growth_Rate')
plt.xlabel('Year')
plt.ylabel('Enrollment Growth Rate (%)')
plt.grid(True)
plt.show()

# %%
plt.plot(trend['Year'], trend['Private Enrollments'], marker='o')
plt.title('Year vs Private Enrollments')
plt.xlabel('Year')
plt.ylabel('Private Enrollments')
plt.grid(True)
plt.show()

# %%
plt.plot(trend['Year'], trend['Public Enrollments'], marker='o')
plt.title('Year vs Public Enrollments')
plt.xlabel('Year')
plt.ylabel('Public Enrollments')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
