# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
analysis_trend = pd.read_csv(r"C:\Users\rawat\Downloads\year.csv")
analysis_trend.head(17)
# Out:
#     Year        India        USA         UK  Australia    Canada
# 0   2007  2,60,00,000  43,00,000  14,00,000   9,00,000  8,00,000
# 1   2008  2,71,00,000  44,00,000  14,20,000   9,20,000  8,20,000
# 2   2009  2,82,00,000  44,50,000  14,50,000   9,40,000  8,30,000
# 3   2010  2,90,00,000  45,00,000  14,60,000   9,50,000  8,40,000
# 4   2011  2,95,00,000  45,50,000  14,70,000   9,60,000  8,50,000
# 5   2012  3,00,00,000  46,00,000  14,80,000   9,70,000  8,60,000
# 6   2013  3,05,00,000  46,50,000  14,90,000   9,80,000  8,70,000
# 7   2014  3,10,00,000  47,00,000  15,00,000   9,90,000  8,80,000
# 8   2015  3,15,00,000  47,50,000  15,10,000  10,00,000  8,90,000
# 9   2016  3,20,00,000  48,00,000  15,20,000  10,10,000  9,00,000
# 10  2017  3,25,00,000  48,50,000  15,30,000  10,20,000  9,10,000
# 11  2018  3,30,00,000  49,00,000  15,40,000  10,30,000  9,20,000
# 12  2019  3,35,00,000  49,50,000  15,50,000  10,40,000  9,30,000
# 13  2020  2,00,00,000  30,00,000  12,00,000   8,50,000  8,00,000
# 14  2021  2,05,00,000  32,00,000  11,50,000   8,00,000  7,50,000
# 15  2022  2,25,00,000  35,00,000  12,50,000   8,70,000  7,80,000
# 16  2023  2,78,00,000  40,00,000  12,30,000   8,60,000  7,70,000

# %%
# Sort the DataFrame by the 'Year' column
df_sorted = analysis_trend.sort_values(by='Year')
df_sorted1 = analysis_trend.sort_values(by='India')

# Create the bar graph
plt.figure(figsize=(10, 6))
plt.bar(analysis_trend['Year'],analysis_trend['India'], color='skyblue', edgecolor='black')

# Adding titles and labels
plt.title('Enrollments Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Enrollments')

# Customizing X-axis values (e.g., setting specific ticks and labels)
plt.xticks(ticks=df_sorted['Year'], labels=[str(year) for year in df_sorted['Year']], rotation=45)
plt.yticks(ticks=df_sorted1['India'], labels=[str(India) for India in df_sorted1['India']], rotation=45)

# Show grid lines
plt.grid(True)

# Display the plot
plt.show()

# %%
trend = pd.read_csv(r"C:\Users\rawat\Downloads\india.csv")
trend.head(100)
# Out:
#     Year  Enrollment_Growth_Rate(%)  Govt Expenditure on Education (%)  \
# 0   2007                        4.5                                3.2
# 1   2008                        4.2                                3.4
# 2   2009                        4.1                                3.6
# 3   2010                        2.8                                3.7
# 4   2011                        1.7                                3.9
# 5   2012                        1.9                                4.0
# 6   2013                        1.7                                4.2
# 7   2014                        1.6                                4.4
# 8   2015                        1.6                                4.5
# 9   2016                        1.5                                4.7
# 10  2017                        1.4                                4.8
# 11  2018                        1.3                                4.9
# 12  2019                        1.5                                5.0
# 13  2020                      -10.4                                5.1
# 14  2021                       -1.7                                5.3
# 15  2022                        3.4                                5.4
# 16  2023                       -2.3                                5.2
#
#     GDP Growth Rate (%)                        Key Impacts Public Enrollments  \
# 0                   8.2           Launch of ICDS expansion        1,60,00,000
# 1                   7.2  Increased investment in education        1,68,00,000
# 2                   8.5          Implementation of RTE Act        1,76,00,000
# 3                  10.3   Expansion of mid-day meal scheme        1,83,00,000
# 4                   6.6       Policy on Right to Education        1,90,00,000
# 5                   5.5       Education for All initiative        1,94,00,000
# 6                   6.4              Launch of Skill India        1,97,00,000
# 7                   7.4      National Early Childhood Care        2,00,00,000
# 8                   8.0           Digital India initiative        2,03,00,000
# 9                   8.2                 GST implementation        2,06,00,000
# 10                  7.0             National Health Policy        2,09,00,000
# 11                  6.1             Ayushman Bharat launch        2,12,00,000
# 12                  4.2                  Education reforms        2,15,00,000
# 13                 -7.0                  COVID-19 pandemic        1,80,00,000
# 14                  8.9                    COVID-19 impact        1,80,00,000
# 15                  6.7                   Recovery efforts        1,85,00,000
# 16                  7.0        Post-COVID recovery efforts        1,82,00,000
#
#    Private Enrollments  Unemployment Rate (%)  Birth Rate (per 1000)  \
# 0          1,00,00,000                    4.0                   22.0
# 1          1,03,00,000                    4.1                   21.8
# 2          1,06,00,000                    4.5                   21.5
# 3          1,07,00,000                    4.3                   21.3
# 4          1,05,00,000                    4.7                   21.1
# 5          1,06,00,000                    5.2                   20.9
# 6          1,08,00,000                    4.9                   20.7
# 7          1,10,00,000                    4.7                   20.5
# 8          1,12,00,000                    4.6                   20.3
# 9          1,14,00,000                    4.5                   20.1
# 10         1,16,00,000                    4.4                   19.9
# 11         1,18,00,000                    4.3                   19.7
# 12         1,20,00,000                    5.0                   19.5
# 13         1,20,00,000                    8.0                   19.3
# 14         1,15,00,000                    7.5                   19.1
# 15         1,20,00,000                    7.0                   18.9
# 16         1,16,00,000                    6.8                   18.7
#
#     Death Rate (per 1000)
# 0                     7.6
# 1                     7.5
# 2                     7.4
# 3                     7.3
# 4                     7.2
# 5                     7.1
# 6                     7.0
# 7                     6.9
# 8                     6.8
# 9                     6.7
# 10                    6.6
# 11                    6.5
# 12                    6.4
# 13                    7.0
# 14                    6.8
# 15                    6.7
# 16                    6.6

# %%
plt.plot(trend['Year'], trend['Enrollment_Growth_Rate(%)'],marker='o')
plt.title('Year vs Enrollment_Growth_Rate')
plt.xlabel('Year')
plt.ylabel('Enrollment_Growth_Rate(%)')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\New folder\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Enrollment_Growth_Rate (%)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 plt.plot(trend['Year'], trend['Enrollment_Growth_Rate (%)'],marker='o')
#       2 plt.title('Year vs Enrollment_Growth_Rate')
#       3 plt.xlabel('Year')
#
# File ~\anaconda3\New folder\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\New folder\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Enrollment_Growth_Rate (%)'

# %%
plt.plot(trend['Year'], trend['Private Enrollments'], marker='o')
plt.title('Year vs Private Enrollments')
plt.xlabel('Year')
plt.ylabel('Private Enrollments')
plt.grid(True)
plt.show()

# %%
plt.plot(trend['Year'], trend['Public Enrollments'], marker='o')
plt.title('Year vs Public Enrollments')
plt.xlabel('Year')
plt.ylabel('Public Enrollments')
plt.grid(True)
plt.show()

# %%
teachers= pd.read_csv(r"C:\Users\rawat\Downloads\teachersattritiondata.csv")
teachers.head(17)

# %%
plt.plot(teachers['Year'], teachers['Public Schools (% Leaving)'], marker='o')
plt.title('Year vs leaving_rate')
plt.xlabel('Year')
plt.ylabel('Public Schools (% Leaving)')
plt.grid(True)
plt.show()

# %%
plt.plot(teachers['Year'], teachers['Private Schools (% Leaving)'])
plt.title('Year vs leaving_rate')
plt.xlabel('Year')
plt.ylabel('Private Schools (% Leaving)')
plt.grid(True)
plt.show()

# %%
academics = pd.read_csv(r"C:\Users\rawat\Downloads\academics.csv")
academics.head(100)

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.bar(academics['Low Performers (%)'],academics['Average Grade (%)'],academics['High Achievers (%)'],color=['red', 'yellow', 'green'])


# Adding titles and labels
plt.title('Total Students vs Achievers Categories')
plt.xlabel('Total Students')
plt.ylabel('Categories')

# Display the plot
plt.show()

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.bar(academics['Extracurricular Participation (%)'],academics['Sports Participation (%)'],academics['Community Service Participation (%)'],color=['red', 'yellow', 'green'])


# Adding titles and labels
plt.title('Total Students vs Extracurricular Activities')
plt.xlabel('Total Students')
plt.ylabel('Categories')

# Display the plot
plt.show()

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
df = pd.read_csv(r"C:\Users\rawat\Downloads\parents_feedback_xyz_school.csv")
df.head()

# %%
# Preprocess the text data
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# %%
def clean_text(text):
    text = re.sub(r'[^a-zA-Z\s]', '', text)  # Remove special characters and numbers
    text = text.lower()  # Convert to lowercase
    text = ' '.join([word for word in text.split() if word not in stop_words])  # Remove stopwords
    return text

df['cleaned_feedback'] = df['Feedback'].apply(clean_text)

# %%
# Sentiment Analysis with VADER
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()

def get_vader_sentiment(text):
    sentiment_dict = sia.polarity_scores(text)
    if sentiment_dict['compound'] >= 0.05:
        return 'positive'
    elif sentiment_dict['compound'] <= -0.05:
        return 'negative'
    else:
        return 'neutral'

df['vader_sentiment'] = df['cleaned_feedback'].apply(get_vader_sentiment)

# %%
# Visualize the Results
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='vader_sentiment', palette='viridis')
plt.title('Sentiment Distribution for Parents\' Feedback (VADER)')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()

# %%
#Loading data or reading the dataset
demographics = pd.read_csv(r"C:\Users\rawat\Downloads\Demographics.csv")
demographics.head(100)

# %%
# Plotting pie charts for gender distribution of each school
for i, school in enumerate(demographics['School Name']):
    labels = ['Male', 'Female']
    sizes = [demographics['Male (%)'][i], demographics['Female (%)'][i]]
    
    plt.figure(i)
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
    plt.title(school)
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# Plotting pie charts for Caste distribution of each school
for i, school in enumerate(demographics['School Name']):
    labels = ['General (%)','OBC (%)','SC/ST (%)',' Other(%)']
    sizes = [demographics['General (%)'][i], demographics['OBC (%)'][i], demographics['SC/ST (%)'][i], demographics['Other (%)'][i]]
    
    plt.figure(i)
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
    plt.title(school)
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# Plotting pie charts for Religion distribution of each school
for i, school in enumerate(demographics['School Name']):
    labels = ['Hindu (%)','Muslim (%)','Sikh (%)','Christian (%)']
    sizes = [demographics['Hindu (%)'][i], demographics['Muslim (%)'][i], demographics['Sikh (%)'][i], demographics['Christian (%)'][i]]
    
    plt.figure(i)
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
    plt.title(school)
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
